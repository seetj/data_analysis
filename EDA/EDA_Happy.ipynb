# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt           
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv('2015.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df_region = pd.pivot_table(df,index = ['Region'])
df_region
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17852/3051817413.py in <module>
# ----> 1 df_region = df.groupby(['Weekday'])
#       2
#       3 df_region
#
# NameError: name 'df' is not defined

# %%
df_region['Happiness Rank'].nsmallest(10).plot(kind = 'bar', figsize = (12,5))
plt.xlabel('Region')
plt.ylabel('Happiness Rank')
plt.title('Average Happiness Rank per Region')
# Out:
# Text(0.5, 1.0, 'Average Happiness Rank per Region')

# %%
plt.figure(figsize=(10,5))
c= df_region.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
#According to this heatmap, happiness score is heavily correlated with
#economy, family, freedom, health, and trust
# Out:
# <AxesSubplot:>

# %%
#trying out seasborn plot function
plt.figure(figsize= (12,8))
ax = sns.barplot(df['Region'],df['Happiness Rank'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# c:\Users\Jason\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Western Europe'),
#  Text(1, 0, 'North America'),
#  Text(2, 0, 'Australia and New Zealand'),
#  Text(3, 0, 'Middle East and Northern Africa'),
#  Text(4, 0, 'Latin America and Caribbean'),
#  Text(5, 0, 'Southeastern Asia'),
#  Text(6, 0, 'Central and Eastern Europe'),
#  Text(7, 0, 'Eastern Asia'),
#  Text(8, 0, 'Sub-Saharan Africa'),
#  Text(9, 0, 'Southern Asia')]

# %%
plt.figure(figsize= (12,8))
scat = sns.relplot(
    df['Health (Life Expectancy)'],df['Economy (GDP per Capita)']
    )
# Out:
# c:\Users\Jason\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
